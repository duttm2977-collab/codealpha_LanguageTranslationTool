# %% [markdown]
# <a href="https://colab.research.google.com/github/duttm2977-collab/codealpha_LanguageTranslationTool/blob/main/Language_Translation_Tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deep-translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator

text = input("Enter text: ")

translated = GoogleTranslator(
    source='auto',
    target='hi'
).translate(text)

print("Translated Text:")
print(translated)
# Out:
# Enter text: Hello my name is Mohit
# Translated Text:
# हेलो मेरा नाम मोहित है

# %%
from deep_translator import GoogleTranslator

text = input("Enter text: ")

target_language = input(
    "Choose language (hi=Hindi, fr=French, es=Spanish): "
)

translated = GoogleTranslator(
    source='auto',
    target=target_language
).translate(text)

print("\nTranslated Text:")
print(translated)
# Out:
# Enter text: Hello my name is Mohit
# Choose language (hi=Hindi, fr=French, es=Spanish): hi
#
# Translated Text:
# हेलो मेरा नाम मोहित है
